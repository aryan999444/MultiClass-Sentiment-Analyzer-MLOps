# %%
import pandas as pd

# %%
try:
    df = pd.read_csv('Dataset-SA.csv')
except UnicodeDecodeError:
    df = pd.read_csv('Dataset-SA.csv', encoding='latin-1')

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# positive    166581
# negative     28232
# neutral      10239
# Name: count, dtype: int64
